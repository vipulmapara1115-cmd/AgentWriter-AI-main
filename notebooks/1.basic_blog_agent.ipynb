# %%
from __future__ import annotations

import operator
from typing import TypedDict, List, Annotated

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send
import os
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

import psycopg
from psycopg.rows import dict_row
from langgraph.checkpoint.postgres import PostgresSaver
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
def get_database_url():
    database_url = os.getenv("DATABASE_URL")

    if not database_url:
        raise ValueError(
            "DATABASE_URL is missing. Please add your Render PostgreSQL External Database URL to .env"
        )

    if "sslmode=" not in database_url:
        separator = "&" if "?" in database_url else "?"
        database_url = f"{database_url}{separator}sslmode=require"

    return database_url

# %%
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
if not GROQ_API_KEY:
    raise ValueError("GROQ_API_KEY is missing. Please add it to your .env file.")

# %%
class Task(BaseModel):
    id: int
    title: str
    brief: str = Field(..., description="What to cover")

# %%
class Plan(BaseModel):
    blog_title: str
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    # reducer: results from workers get concatenated automatically
    sections: Annotated[List[str], operator.add]
    final: str

# %%
llm = ChatGroq(
    model="openai/gpt-oss-120b",
    api_key=GROQ_API_KEY
)

# %%
def orchestrator(state: State) -> dict:

    plan = llm.with_structured_output(Plan).invoke(
        [
            SystemMessage(
                content=(
                    "Create a blog plan with 5-7 sections on the following topic."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )
    return {"plan": plan}

# %%
def fanout(state: State):
    return [Send("worker", {"task": task, "topic": state["topic"], "plan": state["plan"]})
            for task in state["plan"].tasks]

# %%
def worker(payload: dict) -> dict:

    # payload contains what we sent
    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    blog_title = plan.blog_title

    section_md = llm.invoke(
        [
            SystemMessage(content="Write one clean Markdown section."),
            HumanMessage(
                content=(
                    f"Blog: {blog_title}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Brief: {task.brief}\n\n"
                    "Return only the section content in Markdown."
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
from pathlib import Path

def reducer(state: State) -> dict:
    
    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()

    final_md = f"# {title}\n\n{body}\n"

    # ---- save to file ----
    filename = title.lower().replace(" ", "_") + ".md"
    output_path = Path(filename)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

# %%
# =========================
# PostgreSQL Checkpointer
# =========================
DATABASE_URL = get_database_url()

_conn = psycopg.connect(
    DATABASE_URL,
    autocommit=True,
    row_factory=dict_row
)

checkpointer = PostgresSaver(_conn)
checkpointer.setup()

# %%
app = g.compile(checkpointer=checkpointer)

app

# %%
config = {
        "configurable": {
            "thread_id": "test_thread_id"
        }
    }

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []}, config=config)

# %%
out
# Out:
# {'topic': 'Write a blog on Self Attention',
#  'plan': Plan(blog_title='Understanding Self-Attention: The Core of Modern Deep Learning', tasks=[Task(id=1, title='Introduction to Attention Mechanisms', brief='Explain the concept of attention in neural networks, its motivation, and how it differs from traditional architectures.'), Task(id=2, title='What Is Self-Attention?', brief='Define self-attention, illustrate the intuition behind it, and describe its role in processing sequences.'), Task(id=3, title='Mathematical Formulation', brief='Present the equations for query, key, value vectors, scaled dot‑product attention, and multi‑head attention with clear examples.'), Task(id=4, title='Self-Attention in Transformers', brief='Show how self-attention is integrated into the Transformer encoder and decoder, and why it enables parallelism and long‑range dependencies.'), Task(id=5, title='Practical Implementation Tips', brief='Discuss common implementation details: masking, positional encoding, efficient matrix operations, and handling large sequences.'), Task(id=6, title='Applications and Real‑World Examples', brief='Highlight key use‑cases such as NLP (BERT, GPT), vision (ViT), speech, and multimodal models, emphasizing performance gains.'), Task(id=7, title='Future Directions & Conclusion', brief='Summarize the impact of self‑attention, outline emerging research (sparse attention, linear‑time variants), and wrap up with take‑aways.')]),
#  'sections': ['## Introduction to Attention Mechanisms\n\nIn the landscape of neural networks, **attention** has emerged as a powerful paradigm that enables models to dynamically focus on the most relevant parts of their input when producing an output. Rather than treating every element of a sequence—or every pixel of an image—with equal importance, attention mechanisms assign learnable weights that highlight salient information and suppress noise. This simple yet profound idea has reshaped how we design models for language, vision, and multimodal tasks.\n\n### Why Attention?\n\n1. **Long‑range dependencies** – Traditional feed‑forward or recurrent architectures struggle to capture relationships between distant tokens because information must be propagated step‑by‑step (in RNNs) or diluted across many layers (in CNNs). Attention bypasses this bottleneck by allowing each output position to directly attend to any input position, regardless of distance.\n\n2. **Interpretability** – The attention weights can be visualized, offering insight into *what* the model is looking at when making a prediction. This transparency is valuable for debugging, trust, and scientific discovery.\n\n3. **Parallelism** – Unlike recurrent models that process sequences sequentially, many attention formulations (e.g., scaled dot‑product attention) can be computed in parallel across all positions, leading to significant speedups on modern hardware.\n\n### How Attention Differs from Traditional Architectures\n\n| Aspect | Traditional RNN/CNN | Attention‑based Models |\n|--------|---------------------|------------------------|\n| **Information flow** | Sequential (RNN) or local receptive fields (CNN) | Direct, global connections via weighted sums |\n| **Dependency range** | Limited by depth or recurrence steps | Unlimited; any token can influence any other token |\n| **Computation pattern** | Often serial (RNN) or hierarchical (CNN) | Highly parallelizable matrix operations |\n| **Parameter sharing** | Same weights applied across time/space | Separate *query*, *key*, and *value* projections for each head/layer |\n| **Interpretability** | Implicit, hidden states are opaque | Explicit attention maps reveal focus areas |\n\n### The Core Idea\n\nAt its heart, attention computes a **weighted aggregation** of value vectors (`V`) based on similarity scores between a *query* (`Q`) and a set of *keys* (`K`). The classic formulation—*scaled dot‑product attention*—is:\n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax}\\!\\left(\\frac{QK^\\top}{\\sqrt{d_k}}\\right) V\n\\]\n\n- **Query (Q)**: Represents the element that is seeking information (e.g., the current word being generated).  \n- **Key (K)**: Encodes each candidate element that could provide information (e.g., all words in the source sentence).  \n- **Value (V)**: Contains the actual content to be aggregated (often the same as the keys but transformed).  \n\nThe softmax normalizes the similarity scores into a probability distribution, ensuring the resulting weighted sum is a convex combination of the values. This mechanism can be applied **self‑attention** (where Q, K, V all come from the same sequence) or **cross‑attention** (where Q comes from one modality and K/V from another).\n\nBy stacking multiple attention layers and augmenting them with feed‑forward networks, positional encodings, and multi‑head projections, modern architectures—most notably the Transformer—have demonstrated that attention alone can serve as the primary building block for state‑of‑the‑art models across a wide array of domains.',
#   '## What Is Self-Attention?\n\nSelf‑attention is a mechanism that allows a neural network to weigh different parts of a single input sequence against each other when computing a representation for each element. In other words, each token (or patch, frame, etc.) **attends to** every other token in the same sequence, deciding how much information from the others should influence its own encoding.\n\n### Intuition\n\nImagine you are reading a sentence: *“The cat that chased the mouse was hungry.”*  \nTo understand the word **“hungry,”** you need to know that it refers to **“the cat,”** not the mouse. A self‑attention layer can automatically learn to assign a high relevance score from “hungry” to “cat” and a low score to “mouse,” effectively “looking back” at the relevant context.\n\nVisually, you can think of self‑attention as a fully connected graph:\n\n- Each node = a token’s hidden vector.  \n- Edges = learned attention weights that indicate how much one token should consider another.  \n\nThe network computes a weighted sum of all token vectors for each token, using these attention weights as the coefficients.\n\n### Role in Processing Sequences\n\n1. **Contextualization** – By aggregating information from the entire sequence, self‑attention produces context‑aware embeddings for every position, replacing the need for fixed‑size windows used in traditional convolution or recurrence.  \n2. **Parallelism** – Unlike recurrent models, attention scores for all token pairs can be computed simultaneously, enabling efficient GPU/TPU utilization.  \n3. **Long‑range dependencies** – Since every token can directly attend to any other, the model can capture relationships across arbitrarily long distances without the vanishing‑gradient problems of RNNs.  \n4. **Flexibility** – The same mechanism works for text, images (as patches), audio frames, or any ordered set of embeddings, making it a universal building block for modern deep‑learning architectures.  \n\nIn short, self‑attention turns a raw sequence into a richly interlinked representation where each element is informed by the whole, laying the foundation for the powerful transformer models that dominate today’s AI landscape.',
#   '## Mathematical Formulation\n\n### 1. From Tokens to **Q**, **K**, **V**\n\nGiven an input sequence of \\(n\\) tokens, we first embed each token into a vector \\(\\mathbf{x}_i \\in \\mathbb{R}^{d_{\\text{model}}}\\).  \nA single self‑attention layer learns three linear projections:\n\n\\[\n\\begin{aligned}\n\\mathbf{q}_i &= \\mathbf{x}_i \\mathbf{W}^{Q} \\qquad &\\in \\mathbb{R}^{d_k} \\\\\n\\mathbf{k}_i &= \\mathbf{x}_i \\mathbf{W}^{K} \\qquad &\\in \\mathbb{R}^{d_k} \\\\\n\\mathbf{v}_i &= \\mathbf{x}_i \\mathbf{W}^{V} \\qquad &\\in \\mathbb{R}^{d_v}\n\\end{aligned}\n\\]\n\n- \\(\\mathbf{W}^{Q},\\mathbf{W}^{K} \\in \\mathbb{R}^{d_{\\text{model}}\\times d_k}\\)  \n- \\(\\mathbf{W}^{V} \\in \\mathbb{R}^{d_{\\text{model}}\\times d_v}\\)\n\nStacking the vectors for all tokens yields the matrices  \n\n\\[\n\\mathbf{Q}= \\mathbf{X}\\mathbf{W}^{Q}\\in\\mathbb{R}^{n\\times d_k},\\;\n\\mathbf{K}= \\mathbf{X}\\mathbf{W}^{K}\\in\\mathbb{R}^{n\\times d_k},\\;\n\\mathbf{V}= \\mathbf{X}\\mathbf{W}^{V}\\in\\mathbb{R}^{n\\times d_v}.\n\\]\n\n---\n\n### 2. Scaled Dot‑Product Attention\n\nThe core operation computes a weighted sum of the values, where the weights come from the similarity of queries and keys:\n\n\\[\n\\text{Attention}(\\mathbf{Q},\\mathbf{K},\\mathbf{V})=\n\\operatorname{softmax}\\!\\left(\\frac{\\mathbf{Q}\\mathbf{K}^{\\top}}{\\sqrt{d_k}}\\right)\\mathbf{V}.\n\\]\n\n- The term \\(\\frac{1}{\\sqrt{d_k}}\\) stabilises gradients for large \\(d_k\\).  \n- The softmax is applied **row‑wise**, producing an \\(n\\times n\\) matrix of attention scores \\(\\mathbf{A}\\).\n\n#### Tiny numeric example  \n\nAssume a 2‑token sequence, \\(d_k = d_v = 2\\), and the following projected vectors:\n\n\\[\n\\mathbf{Q}= \\begin{bmatrix}1 & 0\\\\ 0 & 1\\end{bmatrix},\n\\quad\n\\mathbf{K}= \\begin{bmatrix}1 & 0\\\\ 0 & 1\\end{bmatrix},\n\\quad\n\\mathbf{V}= \\begin{bmatrix}5 & 5\\\\ 10 & 10\\end{bmatrix}.\n\\]\n\n1. **Dot product**  \n   \\(\\mathbf{Q}\\mathbf{K}^{\\top}= \\begin{bmatrix}1 & 0\\\\ 0 & 1\\end{bmatrix}\\).\n\n2. **Scale** (\\(\\sqrt{d_k}= \\sqrt{2}\\approx1.414\\))  \n   \\(\\frac{\\mathbf{Q}\\mathbf{K}^{\\top}}{\\sqrt{2}} = \\begin{bmatrix}0.707 & 0\\\\ 0 & 0.707\\end{bmatrix}\\).\n\n3. **Softmax row‑wise**  \n\n\\[\n\\mathbf{A}= \\begin{bmatrix}\n\\frac{e^{0.707}}{e^{0.707}+e^{0}} & \\frac{e^{0}}{e^{0.707}+e^{0}}\\\\[4pt]\n\\frac{e^{0}}{e^{0}+e^{0.707}} & \\frac{e^{0.707}}{e^{0}+e^{0.707}}\n\\end{bmatrix}\n\\approx\n\\begin{bmatrix}\n0.67 & 0.33\\\\\n0.33 & 0.67\n\\end{bmatrix}.\n\\]\n\n4. **Weighted sum**  \n\n\\[\n\\mathbf{Z}= \\mathbf{A}\\mathbf{V}\n=\n\\begin{bmatrix}\n0.67 & 0.33\\\\\n0.33 & 0.67\n\\end{bmatrix}\n\\begin{bmatrix}\n5 & 5\\\\\n10 & 10\n\\end{bmatrix}\n=\n\\begin{bmatrix}\n7.5 & 7.5\\\\\n7.5 & 7.5\n\\end{bmatrix}.\n\\]\n\nEach token now carries information from the other token, blended according to the learned similarity.\n\n---\n\n### 3. Multi‑Head Attention\n\nInstead of a single set of \\(\\mathbf{Q},\\mathbf{K},\\mathbf{V}\\), we create **\\(h\\) parallel heads**.  \nEach head \\(i\\) has its own projection matrices \\(\\mathbf{W}^{Q}_i,\\mathbf{W}^{K}_i,\\mathbf{W}^{V}_i\\) and computes:\n\n\\[\n\\mathbf{Z}_i = \\operatorname{softmax}\\!\\left(\\frac{\\mathbf{Q}_i\\mathbf{K}_i^{\\top}}{\\sqrt{d_k}}\\right)\\mathbf{V}_i,\n\\qquad\n\\mathbf{Q}_i = \\mathbf{X}\\mathbf{W}^{Q}_i,\\;\n\\mathbf{K}_i = \\mathbf{X}\\mathbf{W}^{K}_i,\\;\n\\mathbf{V}_i = \\mathbf{X}\\mathbf{W}^{V}_i.\n\\]\n\nThe outputs of all heads are concatenated and linearly transformed once more:\n\n\\[\n\\text{MultiHead}(\\mathbf{X}) =\n\\operatorname{Concat}(\\mathbf{Z}_1,\\dots,\\mathbf{Z}_h)\\mathbf{W}^{O},\n\\qquad\n\\mathbf{W}^{O}\\in\\mathbb{R}^{hd_v \\times d_{\\text{model}}}.\n\\]\n\n#### Example with two heads  \n\nLet \\(h=2\\), \\(d_{\\text{model}}=4\\), \\(d_k=d_v=2\\).  \nSuppose after projection we obtain\n\n\\[\n\\begin{aligned}\n\\mathbf{Q}_1 &= \\begin{bmatrix}1&0\\\\0&1\\end{bmatrix}, &\n\\mathbf{K}_1 &= \\begin{bmatrix}1&0\\\ ...
#   '## Self-Attention in Transformers\n\nThe Transformer architecture replaces recurrent or convolutional layers with **self‑attention** modules, allowing each token to interact directly with every other token in the same sequence. This design appears both in the **encoder** and the **decoder**, but the wiring differs slightly to suit their respective roles.\n\n### Encoder: Stacking Self‑Attention Layers\n\n1. **Input embedding + positional encoding** – each token is mapped to a vector and enriched with a sinusoidal (or learned) position vector so the model can distinguish order.\n2. **Multi‑Head Self‑Attention (MHSA)** – the embedded sequence \\(X \\in \\mathbb{R}^{T \\times d}\\) (where \\(T\\) is the sequence length) is projected into three matrices:\n   - Queries \\(Q = XW_Q\\)\n   - Keys    \\(K = XW_K\\)\n   - Values  \\(V = XW_V\\)\n\n   The attention scores are computed as  \n\n   \\[\n   \\text{Attention}(Q,K,V) = \\text{softmax}\\!\\left(\\frac{QK^\\top}{\\sqrt{d_k}}\\right)V\n   \\]\n\n   Each head learns a different sub‑space, and the results are concatenated and linearly projected back to \\(d\\) dimensions.\n\n3. **Add‑&‑Norm** – a residual connection adds the MHSA output to the original input, followed by layer normalization.\n4. **Position‑wise Feed‑Forward Network (FFN)** – a two‑layer MLP applied independently to each position, again wrapped with a residual connection and layer norm.\n\nThese four steps constitute one **encoder block**; stacking \\(N\\) such blocks yields the full encoder. Because every token’s query attends to *all* keys simultaneously, the computation for each position can be performed **in parallel** on modern GPUs/TPUs.\n\n### Decoder: Masked Self‑Attention + Cross‑Attention\n\nThe decoder mirrors the encoder but adds two crucial variations:\n\n| Component | Purpose | Key Difference |\n|-----------|---------|----------------|\n| **Masked Multi‑Head Self‑Attention** | Allows each output token to attend only to earlier positions (causality) | The attention matrix is masked so that positions \\(j > i\\) receive a \\(-\\infty\\) score before the softmax, preventing information leakage from future tokens. |\n| **Multi‑Head Cross‑Attention** | Integrates information from the encoder’s final representations | Queries come from the decoder’s previous layer, while Keys and Values come from the encoder output. This creates a direct link between source and target sequences. |\n| **Feed‑Forward Network** | Same as in the encoder | Applied after each attention sub‑layer. |\n\nThe decoder thus follows the pattern:\n\n1. **Masked self‑attention** → Add‑&‑Norm  \n2. **Cross‑attention (encoder‑decoder)** → Add‑&‑Norm  \n3. **FFN** → Add‑&‑Norm  \n\n### Why Self‑Attention Enables Parallelism\n\n- **Matrix‑based computation:** All queries, keys, and values are generated in a single linear projection, then the dot‑product attention is a batched matrix multiplication (`Q @ K^T`). GPUs excel at these dense operations, allowing the whole sequence to be processed at once.\n- **No recurrence:** Unlike RNNs, there is no step‑wise dependency that forces sequential execution. Even the masked decoder can be unrolled during training because the mask only zeroes out illegal connections; the underlying matrix ops remain parallel.\n\n### Capturing Long‑Range Dependencies\n\n- **Direct pairwise interactions:** The attention score for any pair \\((i, j)\\) is computed explicitly, irrespective of distance. The computational cost grows quadratically with sequence length, but the *effective receptive field* is the full sequence from the first layer onward.\n- **Multi‑head diversity:** Each head can specialize (e.g., one head may focus on syntactic relations, another on semantic co‑reference), enabling the model to capture varied long‑range patterns simultaneously.\n- **Depth amplifies context:** Stacking several encoder/decoder layers allows information to be propagated and refined across many hops, further strengthening the m ...
#   "## Practical Implementation Tips\n\nWhen moving from theory to code, the devil is in the details. Below are the most common pitfalls and proven strategies for getting self‑attention to run efficiently and correctly.\n\n### 1. Masking – Keep the Attention Focused  \n| Use‑Case | Mask Type | How to Build |\n|----------|-----------|--------------|\n| **Causal (autoregressive) models** | Upper‑triangular mask (future tokens blocked) | `torch.triu(torch.ones(seq_len, seq_len), diagonal=1).bool()` |\n| **Padding tokens** | Binary mask where `0` = padding | `attention_mask = (input_ids != pad_token_id).unsqueeze(1).unsqueeze(2)` |\n| **Hybrid (causal + padding)** | Combine both masks via logical OR | `combined_mask = causal_mask | ~attention_mask` |\n\n**Tips**  \n- Store the mask as a **bool** tensor and add it to the attention scores before the softmax (`scores.masked_fill(mask, -inf)`).  \n- Use `torch.float16` for the mask when working in mixed‑precision to avoid extra casts.  \n- For batched inference, broadcast the mask once and reuse it across layers.\n\n### 2. Positional Encoding – Give Order to Tokens  \n| Approach | When to Use | Implementation Highlights |\n|----------|-------------|----------------------------|\n| **Sinusoidal (fixed)** | Small‑to‑medium models, no extra parameters | Compute once: `pos = torch.arange(seq_len).unsqueeze(1)`; `2i`/`2i+1` dimensions use `sin`/`cos`. |\n| **Learned embeddings** | Large models, fine‑tuning on domain‑specific data | `nn.Embedding(max_len, d_model)`; add directly to token embeddings. |\n| **Rotary (RoPE)** | Vision Transformers, LLMs that need relative positions | Apply rotation matrix on query/key pairs: `q_rot, k_rot = apply_rotary(q, k, seq_len)` – libraries like `torch.nn.functional.rotate` or `einops` help. |\n| **ALiBi / T5‑relative bias** | Very long sequences where absolute positions are costly | Store a small set of bias slopes and add them to the attention logits (`bias = slopes * (i - j)`). |\n\n**Tips**  \n- Pre‑compute sinusoidal encodings up to the maximum expected length and cache them on the same device as the model.  \n- When using RoPE or ALiBi, ensure the bias is **broadcastable** across heads (`[batch, heads, seq, seq]`).  \n- For variable‑length inputs, slice the positional tensor to the current sequence length to avoid unnecessary memory.\n\n### 3. Efficient Matrix Operations – Reduce the Quadratic Bottleneck  \n| Technique | What It Does | Code Pattern |\n|-----------|--------------|--------------|\n| **Batch‑first vs. seq‑first** | Aligns memory layout with GEMM kernels | Prefer `batch, seq, dim` for inputs; use `torch.einsum('btd,bhd->bth')` only when necessary. |\n| **Fused QKV projection** | One linear layer produces Q, K, V simultaneously | `qkv = linear(x).reshape(batch, seq, 3, heads, head_dim).permute(2,0,3,1,4)` |\n| **FlashAttention / Xformers** | Kernel that avoids materializing the full `seq×seq` matrix | `from flash_attn import flash_attn_unpadded_qkvpacked` (PyTorch) |\n| **Chunked / Sliding‑window attention** | Reduces complexity to O(seq·window) | Loop over chunks: `for start in range(0, seq, stride): …` |\n\n**Tips**  \n- Keep tensors **contiguous** (`tensor.contiguous()`) before feeding them to custom kernels.  \n- Use `torch.backends.cuda.matmul.allow_tf32 = True` (or the equivalent for your hardware) to speed up FP16/TF32 matmuls.  \n- Profile with `torch.autograd.profiler` to spot unexpected copies or transposes.\n\n### 4. Handling Very Long Sequences – Beyond the Quadratic Wall  \n1. **Sparse / Local Attention**  \n   - Use libraries like `xformers.ops.memory_efficient_attention` or `torch.nn.MultiheadAttention` with `need_weights=False`.  \n   - Define a sparsity pattern (e.g., block‑sparse, sliding window) and pass it to the kernel.\n\n2. **Chunked Processing with Overlap**  \n   - Split the input into overlapping windows (e.g., 1024 tokens with 128‑token overlap).  \n   - Run self‑attention per chunk, then stitch the outputs, di ...
#   '## Applications and Real‑World Examples\n\nSelf‑attention has become the workhorse behind many breakthroughs across AI domains. Below are the most influential use‑cases and the performance gains they unlocked.\n\n| Domain | Representative Models | What Self‑Attention Adds |\n|--------|-----------------------|--------------------------|\n| **Natural Language Processing** | **BERT**, **GPT‑3/4**, **T5**, **RoBERTa** | Enables bidirectional context (BERT) and long‑range dependencies (GPT) without recurrent loops, yielding *10‑30\u202f%* lower perplexity and *5‑15\u202f%* higher downstream task scores (GLUE, SQuAD) compared to LSTM‑based baselines. |\n| **Computer Vision** | **Vision Transformer (ViT)**, **DETR**, **Swin‑Transformer** | Replaces convolutional receptive fields with global token interactions, achieving *≈2\u202f%* higher top‑1 accuracy on ImageNet‑1k while using fewer parameters than ResNet‑50. DETR’s attention‑based object queries eliminate the need for hand‑crafted NMS, simplifying pipelines. |\n| **Speech & Audio** | **Wav2Vec\u202f2.0**, **Conformer**, **Speech‑Transformer** | Learns contextual acoustic representations directly from raw waveforms; self‑attention captures both short‑term phonetic cues and long‑term speaker or prosody patterns, delivering *+12\u202f%* word‑error‑rate reduction on LibriSpeech versus traditional CNN‑RNN hybrids. |\n| **Multimodal & Cross‑Modal** | **CLIP**, **Florence**, **FLAVA**, **Multimodal BERT** | Jointly attends to image patches and text tokens, aligning modalities in a shared space. CLIP, for example, attains *≈70\u202f%* zero‑shot ImageNet accuracy—far beyond classic supervised CNNs—while supporting open‑ended text‑to‑image retrieval. |\n| **Reinforcement Learning** | **Decision Transformer**, **Perceiver‑IO** | Frames trajectories as sequences and applies attention to predict actions, matching or surpassing model‑based RL on Atari and MuJoCo benchmarks with *orders of magnitude* fewer environment interactions. |\n\n### Why These Gains Matter\n- **Scalability** – Attention’s computational pattern maps efficiently onto GPUs/TPUs, allowing models to scale to billions of parameters while still training faster than recurrent alternatives.\n- **Flexibility** – The same attention block can be reused across modalities (text, image, audio) with minimal architectural changes, fostering rapid prototyping of multimodal systems.\n- **Interpretability** – Attention maps provide visual cues about which tokens or patches influence a decision, aiding debugging and model transparency.\n\nCollectively, these real‑world successes demonstrate that self‑attention is not just a theoretical novelty—it is the backbone of the most performant AI systems in production today.',
#   '## Future Directions & Conclusion\n\nSelf‑attention has reshaped the deep‑learning landscape. By allowing each token to weigh every other token dynamically, it has:\n\n- **Unified architectures** – Transformers now dominate NLP, vision, speech, and multimodal tasks.\n- **Scalable learning** – Parallelizable attention enables training on ever‑larger datasets and model sizes.\n- **Improved representational power** – Long‑range dependencies are captured without the vanishing‑gradient issues of recurrent nets.\n\n### Emerging Research Frontiers\n\n| Area | Core Idea | Why It Matters |\n|------|-----------|----------------|\n| **Sparse Attention** | Attend only to a subset of tokens (e.g., local windows, strided patterns, learned sparsity). | Reduces quadratic cost to near‑linear while preserving performance on long sequences. |\n| **Linear‑Time Variants** | Approximate the softmax kernel (e.g., Performer, Linear Transformers, FAVOR+) to achieve O(N) complexity. | Makes true real‑time processing of massive inputs feasible (e.g., DNA sequences, video streams). |\n| **Memory‑Efficient Transformers** | Chunked or recurrent caching, reversible layers, or low‑rank factorization. | Enables training of deeper models on limited GPU memory. |\n| **Adaptive Computation** | Dynamically decide how many attention heads or layers each token needs (e.g., Routing Transformers, Adaptive Span). | Balances accuracy and latency per input, crucial for edge deployment. |\n| **Cross‑Modal & Multimodal Fusion** | Joint self‑attention across text, image, audio, and sensor streams. | Drives next‑generation AI that understands and generates across modalities. |\n\n### Take‑aways\n\n1. **Self‑attention is the backbone of modern AI**, powering state‑of‑the‑art results across domains.  \n2. **Scalability remains the main challenge**; research is converging on sparsity and kernel approximations to break the quadratic barrier.  \n3. **Future models will be smarter, not just bigger**—they’ll allocate attention adaptively, fuse modalities seamlessly, and operate within strict memory/latency budgets.  \n\nIn short, the self‑attention mechanism has opened a new frontier of possibilities. As the community refines its efficiency and extends its reach, we can expect ever more capable and versatile AI systems built on this simple yet powerful idea.'],
#  'final': "# Understanding Self-Attention: The Core of Modern Deep Learning\n\n## Introduction to Attention Mechanisms\n\nIn the landscape of neural networks, **attention** has emerged as a powerful paradigm that enables models to dynamically focus on the most relevant parts of their input when producing an output. Rather than treating every element of a sequence—or every pixel of an image—with equal importance, attention mechanisms assign learnable weights that highlight salient information and suppress noise. This simple yet profound idea has reshaped how we design models for language, vision, and multimodal tasks.\n\n### Why Attention?\n\n1. **Long‑range dependencies** – Traditional feed‑forward or recurrent architectures struggle to capture relationships between distant tokens because information must be propagated step‑by‑step (in RNNs) or diluted across many layers (in CNNs). Attention bypasses this bottleneck by allowing each output position to directly attend to any input position, regardless of distance.\n\n2. **Interpretability** – The attention weights can be visualized, offering insight into *what* the model is looking at when making a prediction. This transparency is valuable for debugging, trust, and scientific discovery.\n\n3. **Parallelism** – Unlike recurrent models that process sequences sequentially, many attention formulations (e.g., scaled dot‑product attention) can be computed in parallel across all positions, leading to significant speedups on modern hardware.\n\n### How Attention Differs from Traditional Architectures\n\n| Aspect | Traditional RNN/CNN | Attention‑based Models |\n|--------|---------------------|------------------------|\n| **Information flow** | Sequential (RNN) or local receptive fields (CNN) | Direct, global connections via weighted sums |\n| **Dependency range** | Limited by depth or recurrence steps | Unlimited; any token can influence any other token |\n| **Computation pattern** | Often serial (RNN) or hierarchical (CNN) | Highly parallelizable matrix operations |\n| **Parameter sharing** | Same weights applied across time/space | Separate *query*, *key*, and *value* projections for each head/layer |\n| **Interpretability** | Implicit, hidden states are opaque | Explicit attention maps reveal focus areas |\n\n### The Core Idea\n\nAt its heart, attention computes a **weighted aggregation** of value vectors (`V`) based on similarity scores between a *query* (`Q`) and a set of *keys* (`K`). The classic formulation—*scaled dot‑product attention*—is:\n\n\\[\n\\text{Attention}(Q, K, V) = \\text{softmax}\\!\\left(\\frac{QK^\\top}{\\sqrt{d_k}}\\right) V\n\\]\n\n- **Query (Q)**: Represents the element that is seeking information (e.g., the current word being generated).  \n- **Key (K)**: Encodes each candidate element that could provide information (e.g., all words in the source sentence).  \n- **Value (V)**: Contains the actual content to be aggregated (often the same as the keys but transformed).  \n\nThe softmax normalizes the similarity scores into a probability distribution, ensuring the resulting weighted sum is a convex combination of the values. This mechanism can be applied **self‑attention** (where Q, K, V all come from the same sequence) or **cross‑attention** (where Q comes from one modality and K/V from another).\n\nBy stacking multiple attention layers and augmenting them with feed‑forward networks, positional encodings, and multi‑head projections, modern architectures—most notably the Transformer—have demonstrated that attention alone can serve as the primary building block for state‑of‑the‑art models across a wide array of domains.\n\n## What Is Self-Attention?\n\nSelf‑attention is a mechanism that allows a neural network to weigh different parts of a single input sequence against each other when computing a representation for each element. In other words, each token (or patch, frame, etc.) **attends to** every other token in the same sequence, deciding how much information f ...
